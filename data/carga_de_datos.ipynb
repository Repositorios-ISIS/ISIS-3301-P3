# %% [markdown]
# # Librerias

# %%
# webdriver ayuda a realizar acciones de navegación en el navegador
from selenium import webdriver
# time ayuda a poder detener el script un tiempo determinado
import time
# Para saber donde estoy :v
import os
#Librerias para trabajar los datos
import pandas as pd
import numpy as np
# Para trabajar con archivos zip
from zipfile import ZipFile

# %% [markdown]
# # Funciones

# %%
# Función para descargar los archivos de los municipios
def descargar_archivos(lista):
    
    """
    Configuración opciones del webdriver
    """
    
    # Ayuda a establecer las preferencias del navegador chrome
    options = webdriver.ChromeOptions()
    prefs = {'download.default_directory': os.getcwd() + '\\data_source'}
    #Permite añadir nuestras preferencias al driver
    options.add_experimental_option("prefs",prefs)
    
    """
    Configuración webdriver
    """
    # Ruta del driver
    PATH = os.getcwd() + '\\chromedriver\\chromedriver.exe'
    # Creamos el driver
    driver = webdriver.Chrome(executable_path=PATH, options = options)
    
    """
    Ahora si la descarga
    """
    
    for muni in lista:        
        file_name = f'./data_source/TerriData{muni}f.xlsx.zip'
        # Para cada municipio, si este zip no esta en "./data_source/", se descarga
        if not os.path.isfile(file_name):
            print('descargando municipio: ' + str(muni))
            try:
                # Buscamos el objeto
                driver.get(f'https://terridata.dnp.gov.co/index-app.html#/perfiles/{muni}')
                time.sleep(2)
                downloadxlsx = driver.find_element_by_id('btnExcel')
                downloadxlsx.click()
            except Exception as e:
                print(str(e))
            # Esperamos 30 segundos porque no quiero que la página banee mi ip
            time.sleep(8)
        print(f'Municipio {muni} descargado.')
        
    #Cerramos el webdriver
    driver.quit()

# %%
# Arregla los tipos del dataframe
def arreglar_tipos(df:pd.DataFrame, types:dict) -> None:
    for value in types:
        try:
            df[value] = df[value].astype(types[value])
        except Exception as e:
            print(f'error in value {value}',str(e))

# %% [markdown]
# # Trabajo con el Dataframe
# ## Paso 1
# Traigo el dataframe y lo limpio

# %%
# Dataframe central
df_main = pd.read_csv('data_source/data_2018_2020.csv',sep=',',index_col=False,low_memory=False)

# Limpieza
df_main = df_main.drop(df_main[df_main['codigo_depto']=='TOTAL'].index,errors='ignore')
df_main = df_main.drop(df_main[df_main['nombre_depto']=='TOTAL'].index,errors='ignore')
df_main = df_main.drop(df_main[df_main['nombre_muni']=='TOTAL'].index,errors='ignore')
df_main = df_main.drop(df_main[df_main['codigo_muni']=='TOTAL'].index,errors='ignore')
df_main = df_main.drop(df_main[df_main['codigo_evento']=='TOTAL'].index,errors='ignore')
df_main = df_main.drop(df_main[df_main['evento']=='TOTAL'].index,errors='ignore')
df_main = df_main.drop(df_main[df_main['edad']=='TOTAL'].index,errors='ignore')
df_main = df_main.drop(df_main[df_main['sexo']=='TOTAL'].index,errors='ignore')

# Lo de los extranjeros
df_main['codigo_depto'] = df_main['codigo_depto'].apply(lambda x : 100 if x == 'Extranjeros' else x)

# Quitamos muertes en el extranjero (columna codigo_depto con el valor 100)
df_main = df_main.drop(df_main[df_main['codigo_depto']==100].index)
# Quitamos sexo indeterminado (columna sexo con el valor "Indeterminado")
df_main = df_main.drop(df_main[df_main['sexo']=='Indeterminado'].index)
# Quitamos muertes de edad desconocida (columna edad con valor "Edad Desconocida")
df_main = df_main.drop(df_main[df_main['edad']=='Edad desconocida'].index)

"""
En la columna edad quitaremos los valores correspondientes a "De 65 y más" dado que en esa columna a 
la vez hay rangos como "De 65-84 años", "De 85-99 años", "De 100 y más" y al ser dos versiones de la 
misma información (aparentemente), decidimos quedarnos con los otros rangos en espera de que nos den 
más info.
"""
df_main = df_main.drop(df_main[df_main['edad']=='De 65 y más'].index)

# Arreglamos los tipos
value_types = {'anio':'int64','codigo_depto':'string','nombre_depto':'string',
               'nombre_muni':'string','codigo_muni':'string','codigo_evento':'int64',
               'evento':'string','sexo':'string','edad':'string','num_casos':'int64'
              }
arreglar_tipos(df_main,value_types)

# Hay que arreglar los rangos de las edades
rangos = {'Menor 1 año':'0-4 años','De 1-4 años':'0-4 años','De 5-14 años':'5-14 años',
          'De 15-44 años':'15-44 años','De 45-64 años':'45-64 años','De 65-84 años':'65+ años',
          'De 85-99 años':'65+ años','De 100 y más':'65+ años'
         }

df_main['edad'] = df_main['edad'].apply(lambda x : rangos[x])

#Los valores que nos hayan quedado iguales deben ser sumados
group_by_parameters = ['anio','codigo_depto','nombre_depto','nombre_muni','codigo_muni',
                       'codigo_evento','evento','edad','sexo']
df_main = df_main.groupby(by=group_by_parameters).sum()
#Para volverlo dataframe denuevo
df_main = df_main.reset_index()

# Imprimo
df_main.head()
# Out:
#    anio codigo_depto nombre_depto nombre_muni codigo_muni  codigo_evento  \
# 0  2018           05    Antioquia   Abejorral       05002            102
# 1  2018           05    Antioquia   Abejorral       05002            106
# 2  2018           05    Antioquia   Abejorral       05002            108
# 3  2018           05    Antioquia   Abejorral       05002            108
# 4  2018           05    Antioquia   Abejorral       05002            108
#
#                              evento      edad     sexo  num_casos
# 0                      Tuberculosis  65+ años  Hombres          1
# 1      Septicemia, excepto neonatal  65+ años  Mujeres          2
# 2  Infecciones respiratorias agudas  0-4 años  Mujeres          1
# 3  Infecciones respiratorias agudas  65+ años  Hombres          4
# 4  Infecciones respiratorias agudas  65+ años  Mujeres          3

# %% [markdown]
# ## Paso 2
# Saco todos los códigos de municipios

# %%
# Aqui saco solo el Caquetá por el test
df_main = df_main[(df_main["nombre_depto"] == "Caquetá")
                 | (df_main["nombre_depto"] =="Antioquia")
                 | (df_main["nombre_depto"] =="Boyacá")
                 | (df_main["nombre_depto"] =="Chocó")
                 | (df_main["nombre_depto"] =="Huila")
                 ]

# %%
# Me quedo con los códigos
muni_list = df_main["codigo_muni"].unique()
muni_list
# Out:
# array(['05002', '05004', '05021', '05030', '05031', '05034', '05038',
#        '05040', '05044', '05045', '05051', '05055', '05059', '05079',
#        '05088', '05086', '05091', '05093', '05107', '05113', '05125',
#        '05129', '05134', '05142', '05145', '05147', '05150', '05154',
#        '05138', '05172', '05190', '05101', '05197', '05206', '05209',
#        '05212', '05120', '05234', '05237', '05240', '05250', '05148',
#        '05697', '05264', '05266', '05282', '05284', '05306', '05308',
#        '05313', '05315', '05318', '05321', '05310', '05347', '05353',
#        '05360', '05361', '05364', '05368', '05376', '05380', '05390',
#        '05400', '05411', '05425', '05440', '05001', '05467', '05475',
#        '05480', '05483', '05495', '05490', '05501', '05543', '05541',
#        '05576', '05579', '05585', '05591', '05604', '05607', '05615',
#        '05628', '05631', '05642', '05647', '05649', '05652', '05656',
#        '05658', '05659', '05660', '05664', '05665', '05667', '05670',
#        '05674', '05679', '05686', '05042', '05690', '05736', '05756',
#        '05761', '05790', '05792', '05809', '05819', '05837', '05789',
#        '05842', '05847', '05854', '05856', '05858', '05861', '05873',
#        '05885', '05887', '05890', '05893', '05895', '05036', '15022',
#        '15047', '15051', '15087', '15090', '15092', '15097', '15104',
#        '15106', '15109', '15114', '15131', '15135', '15162', '15172',
#        '15176', '15180', '15183', '15185', '15187', '15236', '15232',
#        '15189', '15212', '15215', '15218', '15223', '15224', '15226',
#        '15204', '15238', '15244', '15248', '15272', '15276', '15293',
#        '15299', '15317', '15322', '15325', '15296', '15332', '15362',
#        '15367', '15368', '15380', '15403', '15401', '15377', '15425',
#        '15442', '15455', '15464', '15466', '15469', '15476', '15480',
#        '15491', '15494', '15500', '15507', '15511', '15516', '15518',
#        '15522', '15531', '15533', '15537', '15542', '15550', '15572',
#        '15514', '15580', '15599', '15621', '15600', '15632', '15646',
#        '15660', '15664', '15667', '15673', '15676', '15681', '15690',
#        '15693', '15696', '15686', '15720', '15723', '15740', '15753',
#        '15757', '15755', '15759', '15761', '15762', '15764', '15763',
#        '15774', '15776', '15778', '15638', '15790', '15798', '15804',
#        '15806', '15808', '15810', '15814', '15816', '15822', '15001',
#        '15832', '15835', '15837', '15839', '15820', '15842', '15861',
#        '15407', '15879', '15897', '18029', '18094', '18150', '18205',
#        '18247', '18256', '18001', '18410', '18460', '18479', '18592',
#        '18610', '18753', '18756', '18785', '18860', '27006', '27025',
#        '27050', '27073', '27075', '27077', '27099', '27150', '27205',
#        '27160', '27135', '27245', '27250', '27361', '27372', '27413',
#        '27425', '27430', '27450', '27495', '27491', '27001', '27615',
#        '27580', '27600', '27660', '27745', '27787', '27800', '27810',
#        '41006', '41013', '41016', '41020', '41026', '41078', '41132',
#        '41206', '41244', '41298', '41306', '41319', '41349', '41357',
#        '41359', '41378', '41396', '41001', '41483', '41503', '41518',
#        '41524', '41530', '41548', '41551', '41615', '41660', '41668',
#        '41676', '41770', '41791', '41799', '41801', '41797', '41807',
#        '41872', '41885'], dtype=object)

# %% [markdown]
# ## Paso 3
# Aqui realizo la descarga del zip, si no tengo el archivo descargado, lo descargo

# %%
descargar_archivos(muni_list)
# Out:
# Municipio 05002 descargado.
# Municipio 05004 descargado.
# Municipio 05021 descargado.
# Municipio 05030 descargado.
# Municipio 05031 descargado.
# Municipio 05034 descargado.
# Municipio 05038 descargado.
# Municipio 05040 descargado.
# Municipio 05044 descargado.
# Municipio 05045 descargado.
# Municipio 05051 descargado.
# Municipio 05055 descargado.
# Municipio 05059 descargado.
# Municipio 05079 descargado.
# Municipio 05088 descargado.
# Municipio 05086 descargado.
# Municipio 05091 descargado.
# Municipio 05093 descargado.
# Municipio 05107 descargado.
# Municipio 05113 descargado.
# Municipio 05125 descargado.
# Municipio 05129 descargado.
# Municipio 05134 descargado.
# Municipio 05142 descargado.
# Municipio 05145 descargado.
# Municipio 05147 descargado.
# Municipio 05150 descargado.
# Municipio 05154 descargado.
# Municipio 05138 descargado.
# Municipio 05172 descargado.
# Municipio 05190 descargado.
# Municipio 05101 descargado.
# Municipio 05197 descargado.
# Municipio 05206 descargado.
# Municipio 05209 descargado.
# Municipio 05212 descargado.
# Municipio 05120 descargado.
# Municipio 05234 descargado.
# Municipio 05237 descargado.
# Municipio 05240 descargado.
# Municipio 05250 descargado.
# Municipio 05148 descargado.
# Municipio 05697 descargado.
# Municipio 05264 descargado.
# Municipio 05266 descargado.
# Municipio 05282 descargado.
# Municipio 05284 descargado.
# Municipio 05306 descargado.
# Municipio 05308 descargado.
# Municipio 05313 descargado.
# Municipio 05315 descargado.
# Municipio 05318 descargado.
# Municipio 05321 descargado.
# Municipio 05310 descargado.
# Municipio 05347 descargado.
# Municipio 05353 descargado.
# Municipio 05360 descargado.
# Municipio 05361 descargado.
# Municipio 05364 descargado.
# Municipio 05368 descargado.
# Municipio 05376 descargado.
# Municipio 05380 descargado.
# Municipio 05390 descargado.
# Municipio 05400 descargado.
# Municipio 05411 descargado.
# Municipio 05425 descargado.
# Municipio 05440 descargado.
# Municipio 05001 descargado.
# Municipio 05467 descargado.
# Municipio 05475 descargado.
# Municipio 05480 descargado.
# Municipio 05483 descargado.
# Municipio 05495 descargado.
# Municipio 05490 descargado.
# Municipio 05501 descargado.
# Municipio 05543 descargado.
# Municipio 05541 descargado.
# Municipio 05576 descargado.
# Municipio 05579 descargado.
# Municipio 05585 descargado.
# Municipio 05591 descargado.
# Municipio 05604 descargado.
# Municipio 05607 descargado.
# Municipio 05615 descargado.
# Municipio 05628 descargado.
# Municipio 05631 descargado.
# Municipio 05642 descargado.
# Municipio 05647 descargado.
# Municipio 05649 descargado.
# Municipio 05652 descargado.
# Municipio 05656 descargado.
# Municipio 05658 descargado.
# Municipio 05659 descargado.
# Municipio 05660 descargado.
# Municipio 05664 descargado.
# Municipio 05665 descargado.
# Municipio 05667 descargado.
# Municipio 05670 descargado.
# Municipio 05674 descargado.
# Municipio 05679 descargado.
# Municipio 05686 descargado.
# Municipio 05042 descargado.
# Municipio 05690 descargado.
# Municipio 05736 descargado.
# Municipio 05756 descargado.
# Municipio 05761 descargado.
# Municipio 05790 descargado.
# Municipio 05792 descargado.
# Municipio 05809 descargado.
# Municipio 05819 descargado.
# Municipio 05837 descargado.
# Municipio 05789 descargado.
# Municipio 05842 descargado.
# Municipio 05847 descargado.
# Municipio 05854 descargado.
# Municipio 05856 descargado.
# Municipio 05858 descargado.
# Municipio 05861 descargado.
# Municipio 05873 descargado.
# Municipio 05885 descargado.
# Municipio 05887 descargado.
# Municipio 05890 descargado.
# Municipio 05893 descargado.
# Municipio 05895 descargado.
# Municipio 05036 descargado.
# Municipio 15022 descargado.
# Municipio 15047 descargado.
# Municipio 15051 descargado.
# Municipio 15087 descargado.
# Municipio 15090 descargado.
# Municipio 15092 descargado.
# Municipio 15097 descargado.
# Municipio 15104 descargado.
# Municipio 15106 descargado.
# Municipio 15109 descargado.
# Municipio 15114 descargado.
# Municipio 15131 descargado.
# Municipio 15135 descargado.
# Municipio 15162 descargado.
# Municipio 15172 descargado.
# Municipio 15176 descargado.
# Municipio 15180 descargado.
# Municipio 15183 descargado.
# Municipio 15185 descargado.
# Municipio 15187 descargado.
# Municipio 15236 descargado.
# Municipio 15232 descargado.
# Municipio 15189 descargado.
# Municipio 15212 descargado.
# Municipio 15215 descargado.
# Municipio 15218 descargado.
# Municipio 15223 descargado.
# Municipio 15224 descargado.
# Municipio 15226 descargado.
# Municipio 15204 descargado.
# Municipio 15238 descargado.
# Municipio 15244 descargado.
# Municipio 15248 descargado.
# Municipio 15272 descargado.
# Municipio 15276 descargado.
# Municipio 15293 descargado.
# Municipio 15299 descargado.
# Municipio 15317 descargado.
# Municipio 15322 descargado.
# Municipio 15325 descargado.
# Municipio 15296 descargado.
# Municipio 15332 descargado.
# Municipio 15362 descargado.
# Municipio 15367 descargado.
# Municipio 15368 descargado.
# Municipio 15380 descargado.
# Municipio 15403 descargado.
# Municipio 15401 descargado.
# Municipio 15377 descargado.
# Municipio 15425 descargado.
# Municipio 15442 descargado.
# Municipio 15455 descargado.
# Municipio 15464 descargado.
# Municipio 15466 descargado.
# Municipio 15469 descargado.
# Municipio 15476 descargado.
# Municipio 15480 descargado.
# Municipio 15491 descargado.
# Municipio 15494 descargado.
# Municipio 15500 descargado.
# Municipio 15507 descargado.
# Municipio 15511 descargado.
# Municipio 15516 descargado.
# Municipio 15518 descargado.
# Municipio 15522 descargado.
# Municipio 15531 descargado.
# Municipio 15533 descargado.
# Municipio 15537 descargado.
# Municipio 15542 descargado.
# Municipio 15550 descargado.
# Municipio 15572 descargado.
# Municipio 15514 descargado.
# Municipio 15580 descargado.
# Municipio 15599 descargado.
# Municipio 15621 descargado.
# Municipio 15600 descargado.
# Municipio 15632 descargado.
# Municipio 15646 descargado.
# Municipio 15660 descargado.
# Municipio 15664 descargado.
# Municipio 15667 descargado.
# Municipio 15673 descargado.
# Municipio 15676 descargado.
# Municipio 15681 descargado.
# Municipio 15690 descargado.
# Municipio 15693 descargado.
# Municipio 15696 descargado.
# Municipio 15686 descargado.
# Municipio 15720 descargado.
# Municipio 15723 descargado.
# Municipio 15740 descargado.
# Municipio 15753 descargado.
# Municipio 15757 descargado.
# Municipio 15755 descargado.
# Municipio 15759 descargado.
# Municipio 15761 descargado.
# Municipio 15762 descargado.
# Municipio 15764 descargado.
# Municipio 15763 descargado.
# Municipio 15774 descargado.
# Municipio 15776 descargado.
# Municipio 15778 descargado.
# Municipio 15638 descargado.
# Municipio 15790 descargado.
# Municipio 15798 descargado.
# Municipio 15804 descargado.
# Municipio 15806 descargado.
# Municipio 15808 descargado.
# Municipio 15810 descargado.
# Municipio 15814 descargado.
# Municipio 15816 descargado.
# Municipio 15822 descargado.
# Municipio 15001 descargado.
# Municipio 15832 descargado.
# Municipio 15835 descargado.
# Municipio 15837 descargado.
# Municipio 15839 descargado.
# Municipio 15820 descargado.
# Municipio 15842 descargado.
# Municipio 15861 descargado.
# Municipio 15407 descargado.
# Municipio 15879 descargado.
# Municipio 15897 descargado.
# Municipio 18029 descargado.
# Municipio 18094 descargado.
# Municipio 18150 descargado.
# Municipio 18205 descargado.
# Municipio 18247 descargado.
# Municipio 18256 descargado.
# Municipio 18001 descargado.
# Municipio 18410 descargado.
# Municipio 18460 descargado.
# Municipio 18479 descargado.
# Municipio 18592 descargado.
# Municipio 18610 descargado.
# Municipio 18753 descargado.
# Municipio 18756 descargado.
# Municipio 18785 descargado.
# Municipio 18860 descargado.
# Municipio 27006 descargado.
# Municipio 27025 descargado.
# Municipio 27050 descargado.
# Municipio 27073 descargado.
# Municipio 27075 descargado.
# Municipio 27077 descargado.
# Municipio 27099 descargado.
# Municipio 27150 descargado.
# Municipio 27205 descargado.
# Municipio 27160 descargado.
# Municipio 27135 descargado.
# Municipio 27245 descargado.
# Municipio 27250 descargado.
# Municipio 27361 descargado.
# Municipio 27372 descargado.
# Municipio 27413 descargado.
# Municipio 27425 descargado.
# Municipio 27430 descargado.
# Municipio 27450 descargado.
# Municipio 27495 descargado.
# Municipio 27491 descargado.
# Municipio 27001 descargado.
# Municipio 27615 descargado.
# Municipio 27580 descargado.
# Municipio 27600 descargado.
# Municipio 27660 descargado.
# Municipio 27745 descargado.
# Municipio 27787 descargado.
# Municipio 27800 descargado.
# Municipio 27810 descargado.
# Municipio 41006 descargado.
# Municipio 41013 descargado.
# Municipio 41016 descargado.
# Municipio 41020 descargado.
# Municipio 41026 descargado.
# Municipio 41078 descargado.
# Municipio 41132 descargado.
# Municipio 41206 descargado.
# Municipio 41244 descargado.
# Municipio 41298 descargado.
# Municipio 41306 descargado.
# Municipio 41319 descargado.
# Municipio 41349 descargado.
# Municipio 41357 descargado.
# Municipio 41359 descargado.
# Municipio 41378 descargado.
# Municipio 41396 descargado.
# Municipio 41001 descargado.
# Municipio 41483 descargado.
# Municipio 41503 descargado.
# Municipio 41518 descargado.
# Municipio 41524 descargado.
# Municipio 41530 descargado.
# Municipio 41548 descargado.
# Municipio 41551 descargado.
# Municipio 41615 descargado.
# Municipio 41660 descargado.
# Municipio 41668 descargado.
# Municipio 41676 descargado.
# Municipio 41770 descargado.
# Municipio 41791 descargado.
# Municipio 41799 descargado.
# Municipio 41801 descargado.
# Municipio 41797 descargado.
# Municipio 41807 descargado.
# Municipio 41872 descargado.
# Municipio 41885 descargado.

# %% [markdown]
# ## Paso 4
# Creo una variable nueva df_ready, que ca a ir concatenando los resultados de cada iteración, ahora, para cada archivo:
# + Extraigo el zip
# + Traigo su dataframe y lo guardo en una variable "temp"
# + Saco lo que me interesa y realizo limpieza
# + Junto con df_main con un join para mezclar la información
# + Concateno con los datos ya juntados anteriormente en df_ready
# + Borro el archivo que salga del zip

# %%
df_ready = None
first_time = False

for muni in muni_list:
    filename = f'./data_source/TerriData{muni}f.xlsx'
    with ZipFile((filename+'.zip'), 'r') as zip:
        #zip.printdir()
        zip.extractall('./data_source/')
        
    # Cargo el archivo
    value_types = {'Código Departamento':'string','Código Entidad':'string'}
    temp = pd.read_excel(filename,dtype=value_types)

    # Me quedo solo con lo que me interesa
    temp = temp[(temp["Dimensión"] == "Demografía y población") 
                & 
                (
                    (temp["Subcategoría"] == "Población de hombres") 
                    |
                    (temp["Subcategoría"] == "Población de mujeres")
                )
               ]

    # Solo conservo las columnas que quiero
    temp = temp.drop(columns=['Dimensión','Subcategoría','Dato Cualitativo','Mes','Fuente'],errors='ignore')

    # Arreglo los nombres de las columnas
    temp.columns = ['codigo_depto','nombre_depto','codigo_muni','nombre_muni','edad','población','anio','sexo']

    # Toca cambiar los '.' por ',' en la columna población  y visceversa 
    temp['población'] = temp['población'].apply(lambda x : x.replace('.',''))
    temp['población'] = temp['población'].apply(lambda x : x.replace(',','.'))
    temp['población'] = temp['población'].astype('float64')

    # Arreglamos los tipos
    value_types = {'codigo_depto':'string','nombre_depto':'string','codigo_muni':'string',
                   'nombre_muni':'string','edad':'string','población':'int64',
                   'anio':'int64','sexo':'string'
                  }

    arreglar_tipos(temp,value_types)

    # Hay que arreglar los rangos de las edades
    rangos_temp = {'Población de hombres de 00-04':'0-4 años','Población de hombres de  05-09':'5-14 años',
                 'Población de hombres de  10-14':'5-14 años','Población de hombres de  15-19':'15-44 años',
                 'Población de hombres de  20-24':'15-44 años','Población de hombres de  25-29':'15-44 años',
                 'Población de hombres de  30-34':'15-44 años','Población de hombres de  35-39':'15-44 años',
                 'Población de hombres de  40-44':'15-44 años','Población de hombres de  45-49':'45-64 años',
                 'Población de hombres de  50-54':'45-64 años','Población de hombres de  55-59':'45-64 años',
                 'Población de hombres de  60-64':'45-64 años','Población de hombres de  65-69':'65+ años',
                 'Población de hombres de  70-74':'65+ años','Población de hombres de  75-79':'65+ años',
                 'Población de hombres de 80 o más':'65+ años','Población de mujeres de 00-04':'0-4 años',
                 'Población de mujeres de  05-09':'5-14 años','Población de mujeres de  10-14':'5-14 años',
                 'Población de mujeres de  15-19':'15-44 años','Población de mujeres de  20-24':'15-44 años',
                 'Población de mujeres de  25-29':'15-44 años','Población de mujeres de  30-34':'15-44 años',
                 'Población de mujeres de  35-39':'15-44 años','Población de mujeres de  40-44':'15-44 años',
                 'Población de mujeres de  45-49':'45-64 años','Población de mujeres de  50-54':'45-64 años',
                 'Población de mujeres de  55-59':'45-64 años','Población de mujeres de  60-64':'45-64 años',
                 'Población de mujeres de  65-69':'65+ años','Población de mujeres de  70-74':'65+ años',
                 'Población de mujeres de  75-79':'65+ años','Población de mujeres de 80 o más':'65+ años'
                }

    temp['edad'] = temp['edad'].apply(lambda x : rangos_temp[x])

    #Los valores que nos hayan quedado iguales deben ser sumados
    temp_group_by_parameters_1 = ['codigo_depto','nombre_depto','codigo_muni',
                                  'nombre_muni','edad','anio','sexo'
                                 ]
    temp = temp.groupby(by=temp_group_by_parameters_1).sum()
    #Para volverlo dataframe denuevo
    temp = temp.reset_index()
    
    # Juntamos con el dataframe original
    temp_group_by_parameters_2 = ['codigo_depto','nombre_depto','codigo_muni',
                                  'nombre_muni','edad','anio','sexo'
                                 ]
    
    temp_merged = pd.merge(df_main, temp,  on=temp_group_by_parameters_2)
    if first_time:
        df_ready = temp_merged
        first_time = False
    else:
        df_ready = pd.concat([df_ready, temp_merged])
    
    os.remove(filename)

# Visualizamos algún dataframe temporal
temp.head()
# Out:
#   codigo_depto nombre_depto codigo_muni nombre_muni        edad  anio  \
# 0           41        Huila       41885     Yaguará    0-4 años  2020
# 1           41        Huila       41885     Yaguará    0-4 años  2020
# 2           41        Huila       41885     Yaguará  15-44 años  2020
# 3           41        Huila       41885     Yaguará  15-44 años  2020
# 4           41        Huila       41885     Yaguará  45-64 años  2020
#
#       sexo  población
# 0  Hombres        310
# 1  Mujeres        323
# 2  Hombres       1744
# 3  Mujeres       1617
# 4  Hombres        902

# %%
# Visualizamos el dataframe actualmente
df_ready.head()
# Out:
#    anio codigo_depto nombre_depto nombre_muni codigo_muni  codigo_evento  \
# 0  2020           05    Antioquia   Abejorral       05002            102
# 1  2020           05    Antioquia   Abejorral       05002            501
# 2  2020           05    Antioquia   Abejorral       05002            511
# 3  2020           05    Antioquia   Abejorral       05002            512
# 4  2020           05    Antioquia   Abejorral       05002            108
#
#                                               evento        edad     sexo  \
# 0                                       Tuberculosis  15-44 años  Hombres
# 1                 Accidentes de transporte terrestre  15-44 años  Hombres
# 2  Lesiones autoinfligidas intencionalmente (suic...  15-44 años  Hombres
# 3                            Agresiones (homicidios)  15-44 años  Hombres
# 4                   Infecciones respiratorias agudas    65+ años  Hombres
#
#    num_casos  población
# 0          1       4393
# 1          1       4393
# 2          1       4393
# 3          1       4393
# 4          1       1358

# %%
df_ready.to_csv('data_generated/data_ready_test.csv', index = False)
